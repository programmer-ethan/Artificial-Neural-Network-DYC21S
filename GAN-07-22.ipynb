# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from keras.preprocessing import sequence
import numpy as np
import random

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = (X_train/255).reshape(-1,784)
X_test = (X_test/255).reshape(-1,784)

# %%
NOISE_DIM = 100

# %%
from keras.layers.advanced_activations import LeakyReLU

# %%
g = Sequential()
g.add(Dense(units=256, input_dim=NOISE_DIM, activation=LeakyReLU(0.2)))
g.add(Dense(units=512, activation=LeakyReLU(0.2)))
g.add(Dense(units=1024, activation=LeakyReLU(0.2)))
g.add(Dense(units=784, activation="sigmoid"))
g.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
d = Sequential()
d.add(Dense(units=1024, input_dim=784, activation=LeakyReLU(0.2)))
d.add(Dense(units=512, activation=LeakyReLU(0.2)))
d.add(Dense(units=256, activation=LeakyReLU(0.2)))
d.add(Dense(units=1, activation="sigmoid"))
d.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
d.trainable=False

# %%
from keras.layers import Input
from keras.models import Model

gan_input = Input(shape=(NOISE_DIM, ))
x = g(inputs=gan_input)
gan_output = d(x)

# %%
model = Model(gan_input, gan_output)
#model = Sequential()

# %%
model.compile(loss="binary_crossentropy", optimizer="adam",metrics=["accuracy"])

# %%
EPOCHS = 10
BATCH_SIZE=128
num_of_batches = int(X_train.shape[0]/BATCH_SIZE)

for e in range(EPOCHS):
    for nob in range(num_of_batches):
        noise = np.random.normal(0,1,size=[BATCH_SIZE,NOISE_DIM])
        fake_data = g.predict(noise)

        real_data = X_train[np.random.randint(0,X_train.shape[0],size=BATCH_SIZE)]

        X = np.concatenate((real_data, fake_data))
        y = np.zeros(2* BATCH_SIZE)
        y[:BATCH_SIZE] = 0.9

        d.trainable= True
        d_loss = d.train_on_batch(X, y)
        
        d.trainable = False
        noise2 = np.random.normal(0,1,size=[BATCH_SIZE,NOISE_DIM])
        y2 = np.ones(BATCH_SIZE)
        g_loss = model.train_on_batch(noise2,y2)
        
        print("EPOCH=",e+1,"BATCH=",nob+1,"g_loss=", g_loss, "\td_loss=",d_loss)
# Out:
# EPOCH= 1 BATCH= 1 g_loss= [18.293643951416016, 0.0] 	d_loss= [0.16258376836776733, 0.5]
# EPOCH= 1 BATCH= 2 g_loss= [16.259618759155273, 0.0] 	d_loss= [0.1625821590423584, 0.5]
# EPOCH= 1 BATCH= 3 g_loss= [13.343080520629883, 0.0] 	d_loss= [0.1625659465789795, 0.5]
# EPOCH= 1 BATCH= 4 g_loss= [10.420780181884766, 0.0] 	d_loss= [0.16266310214996338, 0.5]
# EPOCH= 1 BATCH= 5 g_loss= [40.586524963378906, 0.0] 	d_loss= [0.17861095070838928, 0.5]
# EPOCH= 1 BATCH= 6 g_loss= [0.3238455355167389, 0.890625] 	d_loss= [1.60724937915802, 0.5]
# EPOCH= 1 BATCH= 7 g_loss= [4.534191131591797, 0.0] 	d_loss= [1.6715599298477173, 0.0]
# EPOCH= 1 BATCH= 8 g_loss= [0.01107783429324627, 1.0] 	d_loss= [0.9899780750274658, 0.5]
# EPOCH= 1 BATCH= 9 g_loss= [5.3649396896362305, 0.0] 	d_loss= [2.7608962059020996, 0.0]
# EPOCH= 1 BATCH= 10 g_loss= [5.741322040557861, 0.0] 	d_loss= [0.5709671378135681, 0.5]
# EPOCH= 1 BATCH= 11 g_loss= [1.4998276233673096, 0.0] 	d_loss= [0.33405905961990356, 0.5]
# EPOCH= 1 BATCH= 12 g_loss= [7.463387489318848, 0.0] 	d_loss= [0.3807394206523895, 0.5]
# EPOCH= 1 BATCH= 13 g_loss= [14.413068771362305, 0.0] 	d_loss= [0.24494239687919617, 0.5]
# EPOCH= 1 BATCH= 14 g_loss= [20.983016967773438, 0.0] 	d_loss= [0.22293336689472198, 0.5]
# EPOCH= 1 BATCH= 15 g_loss= [20.225006103515625, 0.0] 	d_loss= [0.31353119015693665, 0.5]
# EPOCH= 1 BATCH= 16 g_loss= [19.635990142822266, 0.0] 	d_loss= [0.24358542263507843, 0.5]
# EPOCH= 1 BATCH= 17 g_loss= [19.99798583984375, 0.0] 	d_loss= [0.2887272238731384, 0.5]
# EPOCH= 1 BATCH= 18 g_loss= [21.178403854370117, 0.0] 	d_loss= [0.255368709564209, 0.5]
# EPOCH= 1 BATCH= 19 g_loss= [20.77572250366211, 0.0] 	d_loss= [0.20214879512786865, 0.5]
# EPOCH= 1 BATCH= 20 g_loss= [16.014556884765625, 0.0] 	d_loss= [0.2755722999572754, 0.5]
# EPOCH= 1 BATCH= 21 g_loss= [12.555025100708008, 0.0] 	d_loss= [0.20928677916526794, 0.5]
# EPOCH= 1 BATCH= 22 g_loss= [10.36290168762207, 0.0] 	d_loss= [0.2685903310775757, 0.5]
# EPOCH= 1 BATCH= 23 g_loss= [9.576593399047852, 0.0] 	d_loss= [0.25991541147232056, 0.5]
# EPOCH= 1 BATCH= 24 g_loss= [9.662628173828125, 0.0] 	d_loss= [0.18958964943885803, 0.5]
# EPOCH= 1 BATCH= 25 g_loss= [6.695923805236816, 0.0] 	d_loss= [0.24829107522964478, 0.5]
# EPOCH= 1 BATCH= 26 g_loss= [4.288323402404785, 0.0] 	d_loss= [0.17629477381706238, 0.5]
# EPOCH= 1 BATCH= 27 g_loss= [5.607169151306152, 0.0] 	d_loss= [0.22040647268295288, 0.5]
# EPOCH= 1 BATCH= 28 g_loss= [8.288557052612305, 0.0] 	d_loss= [0.19476839900016785, 0.5]
# EPOCH= 1 BATCH= 29 g_loss= [10.155142784118652, 0.0] 	d_loss= [0.17727404832839966, 0.5]
# EPOCH= 1 BATCH= 30 g_loss= [9.842073440551758, 0.0] 	d_loss= [0.20704439282417297, 0.5]
# EPOCH= 1 BATCH= 31 g_loss= [9.254812240600586, 0.0] 	d_loss= [0.17398539185523987, 0.5]
# EPOCH= 1 BATCH= 32 g_loss= [9.289485931396484, 0.0] 	d_loss= [0.18701311945915222, 0.5]
# EPOCH= 1 BATCH= 33 g_loss= [9.211114883422852, 0.0] 	d_loss= [0.18739913403987885, 0.5]
# EPOCH= 1 BATCH= 34 g_loss= [8.597679138183594, 0.0] 	d_loss= [0.17952977120876312, 0.5]
# EPOCH= 1 BATCH= 35 g_loss= [8.562610626220703, 0.0] 	d_loss= [0.17433908581733704, 0.5]
# EPOCH= 1 BATCH= 36 g_loss= [7.905720233917236, 0.0] 	d_loss= [0.17473243176937103, 0.5]
# EPOCH= 1 BATCH= 37 g_loss= [6.449552536010742, 0.0] 	d_loss= [0.17172831296920776, 0.5]
# EPOCH= 1 BATCH= 38 g_loss= [5.471316337585449, 0.0] 	d_loss= [0.17329323291778564, 0.5]
# EPOCH= 1 BATCH= 39 g_loss= [5.7270917892456055, 0.0] 	d_loss= [0.1808992326259613, 0.5]
# EPOCH= 1 BATCH= 40 g_loss= [6.783027648925781, 0.0] 	d_loss= [0.17517459392547607, 0.5]
# EPOCH= 1 BATCH= 41 g_loss= [7.677425861358643, 0.0] 	d_loss= [0.17215660214424133, 0.5]
# EPOCH= 1 BATCH= 42 g_loss= [8.373457908630371, 0.0] 	d_loss= [0.17595511674880981, 0.5]
# EPOCH= 1 BATCH= 43 g_loss= [9.033571243286133, 0.0] 	d_loss= [0.168815478682518, 0.5]
# EPOCH= 1 BATCH= 44 g_loss= [9.893054008483887, 0.0] 	d_loss= [0.17116302251815796, 0.5]
# EPOCH= 1 BATCH= 45 g_loss= [10.554916381835938, 0.0] 	d_loss= [0.17404085397720337, 0.5]
# EPOCH= 1 BATCH= 46 g_loss= [11.047917366027832, 0.0] 	d_loss= [0.16984426975250244, 0.5]
# EPOCH= 1 BATCH= 47 g_loss= [10.465415954589844, 0.0] 	d_loss= [0.16755621135234833, 0.5]
# EPOCH= 1 BATCH= 48 g_loss= [9.845460891723633, 0.0] 	d_loss= [0.17117945849895477, 0.5]
# EPOCH= 1 BATCH= 49 g_loss= [9.342757225036621, 0.0] 	d_loss= [0.17022402584552765, 0.5]
# EPOCH= 1 BATCH= 50 g_loss= [7.960685729980469, 0.0] 	d_loss= [0.16927126049995422, 0.5]
# EPOCH= 1 BATCH= 51 g_loss= [6.94419002532959, 0.0] 	d_loss= [0.17168566584587097, 0.5]
# EPOCH= 1 BATCH= 52 g_loss= [6.541668891906738, 0.0] 	d_loss= [0.17093375325202942, 0.5]
# EPOCH= 1 BATCH= 53 g_loss= [6.5253143310546875, 0.0] 	d_loss= [0.17025792598724365, 0.5]
# EPOCH= 1 BATCH= 54 g_loss= [6.4416093826293945, 0.0] 	d_loss= [0.17414894700050354, 0.5]
# EPOCH= 1 BATCH= 55 g_loss= [6.914791107177734, 0.0] 	d_loss= [0.17649325728416443, 0.5]
# EPOCH= 1 BATCH= 56 g_loss= [8.855762481689453, 0.0] 	d_loss= [0.18074704706668854, 0.5]
# EPOCH= 1 BATCH= 57 g_loss= [10.415667533874512, 0.0] 	d_loss= [0.1814611852169037, 0.5]
# EPOCH= 1 BATCH= 58 g_loss= [11.38869857788086, 0.0] 	d_loss= [0.21872641146183014, 0.5]
# EPOCH= 1 BATCH= 59 g_loss= [4.980343818664551, 0.0] 	d_loss= [0.2735452353954315, 0.5]
# EPOCH= 1 BATCH= 60 g_loss= [15.848918914794922, 0.0] 	d_loss= [1.1843249797821045, 0.0]
# EPOCH= 1 BATCH= 61 g_loss= [19.356569290161133, 0.0] 	d_loss= [0.27833208441734314, 0.5]
# EPOCH= 1 BATCH= 62 g_loss= [4.667448043823242, 0.0] 	d_loss= [0.5336719155311584, 0.5]
# EPOCH= 1 BATCH= 63 g_loss= [16.59524917602539, 0.0] 	d_loss= [4.63347864151001, 0.0]
# EPOCH= 1 BATCH= 64 g_loss= [16.861289978027344, 0.0] 	d_loss= [0.6159896850585938, 0.5]
# EPOCH= 1 BATCH= 65 g_loss= [74.28266906738281, 0.0] 	d_loss= [19.833385467529297, 0.0]
# EPOCH= 1 BATCH= 66 g_loss= [106.70252990722656, 0.0] 	d_loss= [0.31455790996551514, 0.5]
# EPOCH= 1 BATCH= 67 g_loss= [101.55187225341797, 0.0] 	d_loss= [0.20652443170547485, 0.5]
# EPOCH= 1 BATCH= 68 g_loss= [92.26348876953125, 0.0] 	d_loss= [0.2885037660598755, 0.5]
# EPOCH= 1 BATCH= 69 g_loss= [76.40533447265625, 0.0] 	d_loss= [0.36327993869781494, 0.5]
# EPOCH= 1 BATCH= 70 g_loss= [67.07525634765625, 0.0] 	d_loss= [0.3797569274902344, 0.5]
# EPOCH= 1 BATCH= 71 g_loss= [63.428688049316406, 0.0] 	d_loss= [0.365695983171463, 0.5]
# EPOCH= 1 BATCH= 72 g_loss= [47.72883224487305, 0.0] 	d_loss= [0.503840446472168, 0.5]
# EPOCH= 1 BATCH= 73 g_loss= [37.506717681884766, 0.0] 	d_loss= [0.4173224866390228, 0.5]
# EPOCH= 1 BATCH= 74 g_loss= [34.53550720214844, 0.0] 	d_loss= [0.44017288088798523, 0.5]
# EPOCH= 1 BATCH= 75 g_loss= [37.04402160644531, 0.0] 	d_loss= [0.4134542942047119, 0.5]
# EPOCH= 1 BATCH= 76 g_loss= [42.56781005859375, 0.0] 	d_loss= [0.27720552682876587, 0.5]
# EPOCH= 1 BATCH= 77 g_loss= [20.809139251708984, 0.0] 	d_loss= [0.545730710029602, 0.5]
# EPOCH= 1 BATCH= 78 g_loss= [7.42008113861084, 0.0] 	d_loss= [0.36648762226104736, 0.5]
# EPOCH= 1 BATCH= 79 g_loss= [3.284604072570801, 0.0] 	d_loss= [0.5470976829528809, 0.5]
# EPOCH= 1 BATCH= 80 g_loss= [49.32928466796875, 0.0] 	d_loss= [0.5747451186180115, 0.5]
# EPOCH= 1 BATCH= 81 g_loss= [99.59211730957031, 0.0] 	d_loss= [0.349057137966156, 0.5]
# EPOCH= 1 BATCH= 82 g_loss= [127.16062927246094, 0.0] 	d_loss= [0.39381805062294006, 0.5]
# EPOCH= 1 BATCH= 83 g_loss= [145.15011596679688, 0.0] 	d_loss= [0.28730523586273193, 0.5]
# EPOCH= 1 BATCH= 84 g_loss= [167.08151245117188, 0.0] 	d_loss= [0.2874220311641693, 0.5]
# EPOCH= 1 BATCH= 85 g_loss= [192.38739013671875, 0.0] 	d_loss= [0.32754820585250854, 0.5]
# EPOCH= 1 BATCH= 86 g_loss= [220.59259033203125, 0.0] 	d_loss= [0.29210373759269714, 0.5]
# EPOCH= 1 BATCH= 87 g_loss= [249.7678985595703, 0.0] 	d_loss= [0.21000880002975464, 0.5]
# EPOCH= 1 BATCH= 88 g_loss= [253.1844482421875, 0.0] 	d_loss= [0.3707660138607025, 0.5]
# EPOCH= 1 BATCH= 89 g_loss= [257.63360595703125, 0.0] 	d_loss= [0.21678179502487183, 0.5]
# EPOCH= 1 BATCH= 90 g_loss= [265.9895324707031, 0.0] 	d_loss= [0.2697608768939972, 0.5]
# EPOCH= 1 BATCH= 91 g_loss= [277.2810974121094, 0.0] 	d_loss= [0.2658069133758545, 0.5]
# EPOCH= 1 BATCH= 92 g_loss= [289.7650451660156, 0.0] 	d_loss= [0.21770957112312317, 0.5]
# EPOCH= 1 BATCH= 93 g_loss= [294.7957763671875, 0.0] 	d_loss= [0.20828533172607422, 0.5]
# EPOCH= 1 BATCH= 94 g_loss= [287.47296142578125, 0.0] 	d_loss= [0.267568439245224, 0.5]
# EPOCH= 1 BATCH= 95 g_loss= [280.8060607910156, 0.0] 	d_loss= [0.214085191488266, 0.5]
# EPOCH= 1 BATCH= 96 g_loss= [277.8863220214844, 0.0] 	d_loss= [0.26233869791030884, 0.5]
# EPOCH= 1 BATCH= 97 g_loss= [278.0351867675781, 0.0] 	d_loss= [0.2566976547241211, 0.5]
# EPOCH= 1 BATCH= 98 g_loss= [280.7742614746094, 0.0] 	d_loss= [0.21496430039405823, 0.5]
# EPOCH= 1 BATCH= 99 g_loss= [282.26031494140625, 0.0] 	d_loss= [0.18336351215839386, 0.5]
# EPOCH= 1 BATCH= 100 g_loss= [272.033447265625, 0.0] 	d_loss= [0.2639310359954834, 0.5]
# EPOCH= 1 BATCH= 101 g_loss= [257.21795654296875, 0.0] 	d_loss= [0.17893022298812866, 0.5]
# EPOCH= 1 BATCH= 102 g_loss= [248.30291748046875, 0.0] 	d_loss= [0.20117035508155823, 0.5]
# EPOCH= 1 BATCH= 103 g_loss= [239.44009399414062, 0.0] 	d_loss= [0.22523699700832367, 0.5]
# EPOCH= 1 BATCH= 104 g_loss= [231.6007080078125, 0.0] 	d_loss= [0.20341771841049194, 0.5]
# EPOCH= 1 BATCH= 105 g_loss= [223.32318115234375, 0.0] 	d_loss= [0.17636242508888245, 0.5]
# EPOCH= 1 BATCH= 106 g_loss= [204.89581298828125, 0.0] 	d_loss= [0.1976218819618225, 0.5]
# EPOCH= 1 BATCH= 107 g_loss= [177.6500244140625, 0.0] 	d_loss= [0.18838459253311157, 0.5]
# EPOCH= 1 BATCH= 108 g_loss= [154.18507385253906, 0.0] 	d_loss= [0.17651306092739105, 0.5]
# EPOCH= 1 BATCH= 109 g_loss= [121.6795654296875, 0.0] 	d_loss= [0.18254809081554413, 0.5]
# EPOCH= 1 BATCH= 110 g_loss= [93.15327453613281, 0.0] 	d_loss= [0.18380773067474365, 0.5]
# EPOCH= 1 BATCH= 111 g_loss= [73.1597671508789, 0.0] 	d_loss= [0.1768471598625183, 0.5]
# EPOCH= 1 BATCH= 112 g_loss= [57.31303024291992, 0.0] 	d_loss= [0.17704036831855774, 0.5]
# EPOCH= 1 BATCH= 113 g_loss= [46.62266540527344, 0.0] 	d_loss= [0.17966151237487793, 0.5]
# EPOCH= 1 BATCH= 114 g_loss= [37.685054779052734, 0.0] 	d_loss= [0.17244455218315125, 0.5]
# EPOCH= 1 BATCH= 115 g_loss= [31.369224548339844, 0.0] 	d_loss= [0.17183728516101837, 0.5]
# EPOCH= 1 BATCH= 116 g_loss= [28.129547119140625, 0.0] 	d_loss= [0.17962676286697388, 0.5]
# EPOCH= 1 BATCH= 117 g_loss= [27.82552146911621, 0.0] 	d_loss= [0.17333707213401794, 0.5]
# EPOCH= 1 BATCH= 118 g_loss= [27.831430435180664, 0.0] 	d_loss= [0.17109817266464233, 0.5]
# EPOCH= 1 BATCH= 119 g_loss= [26.921709060668945, 0.0] 	d_loss= [0.17202846705913544, 0.5]
# EPOCH= 1 BATCH= 120 g_loss= [24.350223541259766, 0.0] 	d_loss= [0.17714941501617432, 0.5]
# EPOCH= 1 BATCH= 121 g_loss= [22.081857681274414, 0.0] 	d_loss= [0.17115500569343567, 0.5]
# EPOCH= 1 BATCH= 122 g_loss= [20.908584594726562, 0.0] 	d_loss= [0.17002953588962555, 0.5]
# EPOCH= 1 BATCH= 123 g_loss= [21.072805404663086, 0.0] 	d_loss= [0.17487794160842896, 0.5]
# EPOCH= 1 BATCH= 124 g_loss= [22.09429168701172, 0.0] 	d_loss= [0.1725458800792694, 0.5]
# EPOCH= 1 BATCH= 125 g_loss= [22.60769271850586, 0.0] 	d_loss= [0.16875608265399933, 0.5]
# EPOCH= 1 BATCH= 126 g_loss= [21.579952239990234, 0.0] 	d_loss= [0.17191533744335175, 0.5]
# EPOCH= 1 BATCH= 127 g_loss= [19.392799377441406, 0.0] 	d_loss= [0.1695268750190735, 0.5]
# EPOCH= 1 BATCH= 128 g_loss= [17.811357498168945, 0.0] 	d_loss= [0.16878405213356018, 0.5]
# EPOCH= 1 BATCH= 129 g_loss= [17.618066787719727, 0.0] 	d_loss= [0.1702156662940979, 0.5]
# EPOCH= 1 BATCH= 130 g_loss= [18.23777198791504, 0.0] 	d_loss= [0.17066030204296112, 0.5]
# EPOCH= 1 BATCH= 131 g_loss= [18.749183654785156, 0.0] 	d_loss= [0.16866686940193176, 0.5]
# EPOCH= 1 BATCH= 132 g_loss= [18.440563201904297, 0.0] 	d_loss= [0.17140927910804749, 0.5]
# EPOCH= 1 BATCH= 133 g_loss= [17.625322341918945, 0.0] 	d_loss= [0.16969670355319977, 0.5]
# EPOCH= 1 BATCH= 134 g_loss= [16.704988479614258, 0.0] 	d_loss= [0.16852712631225586, 0.5]
# EPOCH= 1 BATCH= 135 g_loss= [16.08208465576172, 0.0] 	d_loss= [0.169767826795578, 0.5]
# EPOCH= 1 BATCH= 136 g_loss= [16.00332260131836, 0.0] 	d_loss= [0.16986748576164246, 0.5]
# EPOCH= 1 BATCH= 137 g_loss= [16.156993865966797, 0.0] 	d_loss= [0.16772840917110443, 0.5]
# EPOCH= 1 BATCH= 138 g_loss= [16.47504234313965, 0.0] 	d_loss= [0.1691872477531433, 0.5]
# EPOCH= 1 BATCH= 139 g_loss= [16.576841354370117, 0.0] 	d_loss= [0.16766852140426636, 0.5]
# EPOCH= 1 BATCH= 140 g_loss= [16.083457946777344, 0.0] 	d_loss= [0.16888019442558289, 0.5]
# EPOCH= 1 BATCH= 141 g_loss= [15.31120491027832, 0.0] 	d_loss= [0.1668105274438858, 0.5]
# EPOCH= 1 BATCH= 142 g_loss= [14.509330749511719, 0.0] 	d_loss= [0.1676974892616272, 0.5]
# EPOCH= 1 BATCH= 143 g_loss= [14.490829467773438, 0.0] 	d_loss= [0.16830971837043762, 0.5]
# EPOCH= 1 BATCH= 144 g_loss= [14.688291549682617, 0.0] 	d_loss= [0.1678270548582077, 0.5]
# EPOCH= 1 BATCH= 145 g_loss= [14.909260749816895, 0.0] 	d_loss= [0.1707686185836792, 0.5]
# EPOCH= 1 BATCH= 146 g_loss= [14.73267936706543, 0.0] 	d_loss= [0.1670549064874649, 0.5]
# EPOCH= 1 BATCH= 147 g_loss= [14.487464904785156, 0.0] 	d_loss= [0.16653954982757568, 0.5]
# EPOCH= 1 BATCH= 148 g_loss= [13.933258056640625, 0.0] 	d_loss= [0.1671658754348755, 0.5]
# EPOCH= 1 BATCH= 149 g_loss= [13.714265823364258, 0.0] 	d_loss= [0.16739636659622192, 0.5]
# EPOCH= 1 BATCH= 150 g_loss= [13.613054275512695, 0.0] 	d_loss= [0.16684585809707642, 0.5]
# EPOCH= 1 BATCH= 151 g_loss= [13.57878303527832, 0.0] 	d_loss= [0.1663840115070343, 0.5]
# EPOCH= 1 BATCH= 152 g_loss= [13.458226203918457, 0.0] 	d_loss= [0.16664722561836243, 0.5]
# EPOCH= 1 BATCH= 153 g_loss= [13.347555160522461, 0.0] 	d_loss= [0.16639751195907593, 0.5]
# EPOCH= 1 BATCH= 154 g_loss= [13.139642715454102, 0.0] 	d_loss= [0.16699306666851044, 0.5]
# EPOCH= 1 BATCH= 155 g_loss= [12.881296157836914, 0.0] 	d_loss= [0.1670600175857544, 0.5]
# EPOCH= 1 BATCH= 156 g_loss= [12.692602157592773, 0.0] 	d_loss= [0.16675715148448944, 0.5]
# EPOCH= 1 BATCH= 157 g_loss= [12.612690925598145, 0.0] 	d_loss= [0.1665816605091095, 0.5]
# EPOCH= 1 BATCH= 158 g_loss= [12.722795486450195, 0.0] 	d_loss= [0.16655997931957245, 0.5]
# EPOCH= 1 BATCH= 159 g_loss= [12.862903594970703, 0.0] 	d_loss= [0.16763269901275635, 0.5]
# EPOCH= 1 BATCH= 160 g_loss= [12.505425453186035, 0.0] 	d_loss= [0.16613847017288208, 0.5]
# EPOCH= 1 BATCH= 161 g_loss= [12.072437286376953, 0.0] 	d_loss= [0.1669466644525528, 0.5]
# EPOCH= 1 BATCH= 162 g_loss= [11.820137023925781, 0.0] 	d_loss= [0.16731828451156616, 0.5]
# EPOCH= 1 BATCH= 163 g_loss= [11.756961822509766, 0.0] 	d_loss= [0.166262686252594, 0.5]
# EPOCH= 1 BATCH= 164 g_loss= [11.97964859008789, 0.0] 	d_loss= [0.1657310128211975, 0.5]
# EPOCH= 1 BATCH= 165 g_loss= [12.07204818725586, 0.0] 	d_loss= [0.16642889380455017, 0.5]
# EPOCH= 1 BATCH= 166 g_loss= [11.996576309204102, 0.0] 	d_loss= [0.16676679253578186, 0.5]
# EPOCH= 1 BATCH= 167 g_loss= [11.556290626525879, 0.0] 	d_loss= [0.16551858186721802, 0.5]
# EPOCH= 1 BATCH= 168 g_loss= [11.361885070800781, 0.0] 	d_loss= [0.16720134019851685, 0.5]
# EPOCH= 1 BATCH= 169 g_loss= [11.534261703491211, 0.0] 	d_loss= [0.16638854146003723, 0.5]
# EPOCH= 1 BATCH= 170 g_loss= [11.640159606933594, 0.0] 	d_loss= [0.1662319302558899, 0.5]
# EPOCH= 1 BATCH= 171 g_loss= [11.788766860961914, 0.0] 	d_loss= [0.16623184084892273, 0.5]
# EPOCH= 1 BATCH= 172 g_loss= [12.008832931518555, 0.0] 	d_loss= [0.16787144541740417, 0.5]
# EPOCH= 1 BATCH= 173 g_loss= [11.925567626953125, 0.0] 	d_loss= [0.1673339307308197, 0.5]
# EPOCH= 1 BATCH= 174 g_loss= [11.61607551574707, 0.0] 	d_loss= [0.16679003834724426, 0.5]
# EPOCH= 1 BATCH= 175 g_loss= [11.271832466125488, 0.0] 	d_loss= [0.16606405377388, 0.5]
# EPOCH= 1 BATCH= 176 g_loss= [11.270750045776367, 0.0] 	d_loss= [0.16636940836906433, 0.5]
# EPOCH= 1 BATCH= 177 g_loss= [11.532114028930664, 0.0] 	d_loss= [0.16658413410186768, 0.5]
# EPOCH= 1 BATCH= 178 g_loss= [11.997191429138184, 0.0] 	d_loss= [0.16586078703403473, 0.5]
# EPOCH= 1 BATCH= 179 g_loss= [12.138327598571777, 0.0] 	d_loss= [0.16631102561950684, 0.5]
# EPOCH= 1 BATCH= 180 g_loss= [11.797475814819336, 0.0] 	d_loss= [0.1665724366903305, 0.5]
# EPOCH= 1 BATCH= 181 g_loss= [11.396196365356445, 0.0] 	d_loss= [0.16594378650188446, 0.5]
# EPOCH= 1 BATCH= 182 g_loss= [11.169740676879883, 0.0] 	d_loss= [0.16649357974529266, 0.5]
# EPOCH= 1 BATCH= 183 g_loss= [11.217994689941406, 0.0] 	d_loss= [0.1664922833442688, 0.5]
# EPOCH= 1 BATCH= 184 g_loss= [11.519023895263672, 0.0] 	d_loss= [0.1654866337776184, 0.5]
# EPOCH= 1 BATCH= 185 g_loss= [11.777427673339844, 0.0] 	d_loss= [0.16550759971141815, 0.5]
# EPOCH= 1 BATCH= 186 g_loss= [11.833011627197266, 0.0] 	d_loss= [0.16709277033805847, 0.5]
# EPOCH= 1 BATCH= 187 g_loss= [11.649824142456055, 0.0] 	d_loss= [0.16622459888458252, 0.5]
# EPOCH= 1 BATCH= 188 g_loss= [11.327583312988281, 0.0] 	d_loss= [0.16554659605026245, 0.5]
# EPOCH= 1 BATCH= 189 g_loss= [11.266523361206055, 0.0] 	d_loss= [0.1665767878293991, 0.5]
# EPOCH= 1 BATCH= 190 g_loss= [11.423105239868164, 0.0] 	d_loss= [0.16605165600776672, 0.5]
# EPOCH= 1 BATCH= 191 g_loss= [11.526802062988281, 0.0] 	d_loss= [0.1657719612121582, 0.5]
# EPOCH= 1 BATCH= 192 g_loss= [11.542194366455078, 0.0] 	d_loss= [0.1662219762802124, 0.5]
# EPOCH= 1 BATCH= 193 g_loss= [11.489405632019043, 0.0] 	d_loss= [0.1655174344778061, 0.5]
# EPOCH= 1 BATCH= 194 g_loss= [11.19938850402832, 0.0] 	d_loss= [0.16581721603870392, 0.5]
# EPOCH= 1 BATCH= 195 g_loss= [11.010161399841309, 0.0] 	d_loss= [0.1655653566122055, 0.5]
# EPOCH= 1 BATCH= 196 g_loss= [10.947816848754883, 0.0] 	d_loss= [0.166558176279068, 0.5]
# EPOCH= 1 BATCH= 197 g_loss= [11.133441925048828, 0.0] 	d_loss= [0.1656000316143036, 0.5]
# EPOCH= 1 BATCH= 198 g_loss= [11.391751289367676, 0.0] 	d_loss= [0.1659749150276184, 0.5]
# EPOCH= 1 BATCH= 199 g_loss= [11.549445152282715, 0.0] 	d_loss= [0.16560456156730652, 0.5]
# EPOCH= 1 BATCH= 200 g_loss= [11.338626861572266, 0.0] 	d_loss= [0.16551446914672852, 0.5]
# EPOCH= 1 BATCH= 201 g_loss= [11.186203002929688, 0.0] 	d_loss= [0.16561095416545868, 0.5]
# EPOCH= 1 BATCH= 202 g_loss= [11.114185333251953, 0.0] 	d_loss= [0.1665204018354416, 0.5]
# EPOCH= 1 BATCH= 203 g_loss= [11.066757202148438, 0.0] 	d_loss= [0.16520707309246063, 0.5]
# EPOCH= 1 BATCH= 204 g_loss= [11.655997276306152, 0.0] 	d_loss= [0.1667005568742752, 0.5]
# EPOCH= 1 BATCH= 205 g_loss= [12.006802558898926, 0.0] 	d_loss= [0.16604942083358765, 0.5]
# EPOCH= 1 BATCH= 206 g_loss= [11.860197067260742, 0.0] 	d_loss= [0.16592004895210266, 0.5]
# EPOCH= 1 BATCH= 207 g_loss= [11.202385902404785, 0.0] 	d_loss= [0.16591912508010864, 0.5]
# EPOCH= 1 BATCH= 208 g_loss= [10.853686332702637, 0.0] 	d_loss= [0.16562917828559875, 0.5]
# EPOCH= 1 BATCH= 209 g_loss= [10.914648056030273, 0.0] 	d_loss= [0.1662857085466385, 0.5]
# EPOCH= 1 BATCH= 210 g_loss= [11.38935661315918, 0.0] 	d_loss= [0.1659349799156189, 0.5]
# EPOCH= 1 BATCH= 211 g_loss= [11.859923362731934, 0.0] 	d_loss= [0.16531042754650116, 0.5]
# EPOCH= 1 BATCH= 212 g_loss= [12.038040161132812, 0.0] 	d_loss= [0.1665010303258896, 0.5]
# EPOCH= 1 BATCH= 213 g_loss= [11.816238403320312, 0.0] 	d_loss= [0.16522836685180664, 0.5]
# EPOCH= 1 BATCH= 214 g_loss= [11.320085525512695, 0.0] 	d_loss= [0.16550886631011963, 0.5]
# EPOCH= 1 BATCH= 215 g_loss= [11.106252670288086, 0.0] 	d_loss= [0.1655556559562683, 0.5]
# EPOCH= 1 BATCH= 216 g_loss= [11.46208381652832, 0.0] 	d_loss= [0.16616885364055634, 0.5]
# EPOCH= 1 BATCH= 217 g_loss= [11.749297142028809, 0.0] 	d_loss= [0.1649036407470703, 0.5]
# EPOCH= 1 BATCH= 218 g_loss= [11.921649932861328, 0.0] 	d_loss= [0.16546252369880676, 0.5]
# EPOCH= 1 BATCH= 219 g_loss= [11.6658935546875, 0.0] 	d_loss= [0.16565370559692383, 0.5]
# EPOCH= 1 BATCH= 220 g_loss= [11.417585372924805, 0.0] 	d_loss= [0.16545183956623077, 0.5]
# EPOCH= 1 BATCH= 221 g_loss= [11.507953643798828, 0.0] 	d_loss= [0.16581057012081146, 0.5]
# EPOCH= 1 BATCH= 222 g_loss= [11.507915496826172, 0.0] 	d_loss= [0.1656268984079361, 0.5]
# EPOCH= 1 BATCH= 223 g_loss= [11.385356903076172, 0.0] 	d_loss= [0.16502635180950165, 0.5]
# EPOCH= 1 BATCH= 224 g_loss= [11.386962890625, 0.0] 	d_loss= [0.16554111242294312, 0.5]
# EPOCH= 1 BATCH= 225 g_loss= [11.432002067565918, 0.0] 	d_loss= [0.164992094039917, 0.5]
# EPOCH= 1 BATCH= 226 g_loss= [11.657035827636719, 0.0] 	d_loss= [0.16572698950767517, 0.5]
# EPOCH= 1 BATCH= 227 g_loss= [11.659299850463867, 0.0] 	d_loss= [0.16550281643867493, 0.5]
# EPOCH= 1 BATCH= 228 g_loss= [11.368136405944824, 0.0] 	d_loss= [0.16565081477165222, 0.5]
# EPOCH= 1 BATCH= 229 g_loss= [11.21998119354248, 0.0] 	d_loss= [0.1655430793762207, 0.5]
# EPOCH= 1 BATCH= 230 g_loss= [11.413952827453613, 0.0] 	d_loss= [0.16459882259368896, 0.5]
# EPOCH= 1 BATCH= 231 g_loss= [11.789615631103516, 0.0] 	d_loss= [0.16543051600456238, 0.5]
# EPOCH= 1 BATCH= 232 g_loss= [12.089126586914062, 0.0] 	d_loss= [0.1650228500366211, 0.5]
# EPOCH= 1 BATCH= 233 g_loss= [11.951648712158203, 0.0] 	d_loss= [0.16570736467838287, 0.5]
# EPOCH= 1 BATCH= 234 g_loss= [11.557474136352539, 0.0] 	d_loss= [0.16547220945358276, 0.5]
# EPOCH= 1 BATCH= 235 g_loss= [11.298572540283203, 0.0] 	d_loss= [0.16504812240600586, 0.5]
# EPOCH= 1 BATCH= 236 g_loss= [11.187238693237305, 0.0] 	d_loss= [0.16658103466033936, 0.5]
# EPOCH= 1 BATCH= 237 g_loss= [11.177679061889648, 0.0] 	d_loss= [0.16493183374404907, 0.5]
# EPOCH= 1 BATCH= 238 g_loss= [11.380120277404785, 0.0] 	d_loss= [0.16529826819896698, 0.5]
# EPOCH= 1 BATCH= 239 g_loss= [11.698995590209961, 0.0] 	d_loss= [0.16607575118541718, 0.5]
# EPOCH= 1 BATCH= 240 g_loss= [11.67792797088623, 0.0] 	d_loss= [0.1656610667705536, 0.5]
# EPOCH= 1 BATCH= 241 g_loss= [11.533164978027344, 0.0] 	d_loss= [0.1648755669593811, 0.5]
# EPOCH= 1 BATCH= 242 g_loss= [11.242914199829102, 0.0] 	d_loss= [0.16715487837791443, 0.5]
# EPOCH= 1 BATCH= 243 g_loss= [10.942573547363281, 0.0] 	d_loss= [0.16503587365150452, 0.5]
# EPOCH= 1 BATCH= 244 g_loss= [11.121774673461914, 0.0] 	d_loss= [0.16544590890407562, 0.5]
# EPOCH= 1 BATCH= 245 g_loss= [11.470686912536621, 0.0] 	d_loss= [0.16517090797424316, 0.5]
# EPOCH= 1 BATCH= 246 g_loss= [11.5563383102417, 0.0] 	d_loss= [0.1649826169013977, 0.5]
# EPOCH= 1 BATCH= 247 g_loss= [11.343063354492188, 0.0] 	d_loss= [0.16487747430801392, 0.5]
# EPOCH= 1 BATCH= 248 g_loss= [11.169784545898438, 0.0] 	d_loss= [0.16476845741271973, 0.5]
# EPOCH= 1 BATCH= 249 g_loss= [11.236146926879883, 0.0] 	d_loss= [0.16518892347812653, 0.5]
# EPOCH= 1 BATCH= 250 g_loss= [11.368491172790527, 0.0] 	d_loss= [0.16458269953727722, 0.5]
# EPOCH= 1 BATCH= 251 g_loss= [11.47089958190918, 0.0] 	d_loss= [0.1655568778514862, 0.5]
# EPOCH= 1 BATCH= 252 g_loss= [11.375575065612793, 0.0] 	d_loss= [0.16490299999713898, 0.5]
# EPOCH= 1 BATCH= 253 g_loss= [11.157285690307617, 0.0] 	d_loss= [0.16534367203712463, 0.5]
# EPOCH= 1 BATCH= 254 g_loss= [11.108602523803711, 0.0] 	d_loss= [0.16461992263793945, 0.5]
# EPOCH= 1 BATCH= 255 g_loss= [11.296651840209961, 0.0] 	d_loss= [0.16490215063095093, 0.5]
# EPOCH= 1 BATCH= 256 g_loss= [11.5590181350708, 0.0] 	d_loss= [0.16518040001392365, 0.5]
# EPOCH= 1 BATCH= 257 g_loss= [11.54278564453125, 0.0] 	d_loss= [0.16456443071365356, 0.5]
# EPOCH= 1 BATCH= 258 g_loss= [11.399078369140625, 0.0] 	d_loss= [0.16495168209075928, 0.5]
# EPOCH= 1 BATCH= 259 g_loss= [11.177440643310547, 0.0] 	d_loss= [0.16525898873806, 0.5]
# EPOCH= 1 BATCH= 260 g_loss= [11.327865600585938, 0.0] 	d_loss= [0.16506588459014893, 0.5]
# EPOCH= 1 BATCH= 261 g_loss= [11.50051498413086, 0.0] 	d_loss= [0.16465160250663757, 0.5]
# EPOCH= 1 BATCH= 262 g_loss= [11.546012878417969, 0.0] 	d_loss= [0.16466276347637177, 0.5]
# EPOCH= 1 BATCH= 263 g_loss= [11.536677360534668, 0.0] 	d_loss= [0.16514936089515686, 0.5]
# EPOCH= 1 BATCH= 264 g_loss= [11.238161087036133, 0.0] 	d_loss= [0.16485558450222015, 0.5]
# EPOCH= 1 BATCH= 265 g_loss= [11.03752326965332, 0.0] 	d_loss= [0.16484667360782623, 0.5]
# EPOCH= 1 BATCH= 266 g_loss= [11.24362564086914, 0.0] 	d_loss= [0.16479595005512238, 0.5]
# EPOCH= 1 BATCH= 267 g_loss= [11.704486846923828, 0.0] 	d_loss= [0.16512927412986755, 0.5]
# EPOCH= 1 BATCH= 268 g_loss= [11.945758819580078, 0.0] 	d_loss= [0.16473644971847534, 0.5]
# EPOCH= 1 BATCH= 269 g_loss= [11.862387657165527, 0.0] 	d_loss= [0.16525763273239136, 0.5]
# EPOCH= 1 BATCH= 270 g_loss= [11.439403533935547, 0.0] 	d_loss= [0.16485495865345, 0.5]
# EPOCH= 1 BATCH= 271 g_loss= [11.310763359069824, 0.0] 	d_loss= [0.16482675075531006, 0.5]
# EPOCH= 1 BATCH= 272 g_loss= [11.528214454650879, 0.0] 	d_loss= [0.16456356644630432, 0.5]
# EPOCH= 1 BATCH= 273 g_loss= [11.803482055664062, 0.0] 	d_loss= [0.16459544003009796, 0.5]
# EPOCH= 1 BATCH= 274 g_loss= [11.919961929321289, 0.0] 	d_loss= [0.16452717781066895, 0.5]
# EPOCH= 1 BATCH= 275 g_loss= [11.633180618286133, 0.0] 	d_loss= [0.16504909098148346, 0.5]
# EPOCH= 1 BATCH= 276 g_loss= [11.332489013671875, 0.0] 	d_loss= [0.1652730107307434, 0.5]
# EPOCH= 1 BATCH= 277 g_loss= [11.23811149597168, 0.0] 	d_loss= [0.16467830538749695, 0.5]
# EPOCH= 1 BATCH= 278 g_loss= [11.51205062866211, 0.0] 	d_loss= [0.16462162137031555, 0.5]
# EPOCH= 1 BATCH= 279 g_loss= [11.980918884277344, 0.0] 	d_loss= [0.1649245023727417, 0.5]
# EPOCH= 1 BATCH= 280 g_loss= [11.976761817932129, 0.0] 	d_loss= [0.16436952352523804, 0.5]
# EPOCH= 1 BATCH= 281 g_loss= [11.520286560058594, 0.0] 	d_loss= [0.16509220004081726, 0.5]
# EPOCH= 1 BATCH= 282 g_loss= [11.054975509643555, 0.0] 	d_loss= [0.164667010307312, 0.5]
# EPOCH= 1 BATCH= 283 g_loss= [11.159534454345703, 0.0] 	d_loss= [0.16469524800777435, 0.5]
# EPOCH= 1 BATCH= 284 g_loss= [11.576447486877441, 0.0] 	d_loss= [0.164676696062088, 0.5]
# EPOCH= 1 BATCH= 285 g_loss= [12.038890838623047, 0.0] 	d_loss= [0.16394370794296265, 0.5]
# EPOCH= 1 BATCH= 286 g_loss= [12.042007446289062, 0.0] 	d_loss= [0.16500522196292877, 0.5]
# EPOCH= 1 BATCH= 287 g_loss= [11.751317977905273, 0.0] 	d_loss= [0.16430339217185974, 0.5]
# EPOCH= 1 BATCH= 288 g_loss= [11.608024597167969, 0.0] 	d_loss= [0.16428741812705994, 0.5]
# EPOCH= 1 BATCH= 289 g_loss= [11.649319648742676, 0.0] 	d_loss= [0.1641615331172943, 0.5]
# EPOCH= 1 BATCH= 290 g_loss= [11.81364917755127, 0.0] 	d_loss= [0.16422376036643982, 0.5]
# EPOCH= 1 BATCH= 291 g_loss= [12.17025089263916, 0.0] 	d_loss= [0.1642678827047348, 0.5]
# EPOCH= 1 BATCH= 292 g_loss= [12.336920738220215, 0.0] 	d_loss= [0.16449770331382751, 0.5]
# EPOCH= 1 BATCH= 293 g_loss= [12.070478439331055, 0.0] 	d_loss= [0.1654593050479889, 0.5]
# EPOCH= 1 BATCH= 294 g_loss= [11.65909194946289, 0.0] 	d_loss= [0.16418026387691498, 0.5]
# EPOCH= 1 BATCH= 295 g_loss= [11.743057250976562, 0.0] 	d_loss= [0.16514281928539276, 0.5]
# EPOCH= 1 BATCH= 296 g_loss= [12.234967231750488, 0.0] 	d_loss= [0.16446879506111145, 0.5]
# EPOCH= 1 BATCH= 297 g_loss= [12.51303768157959, 0.0] 	d_loss= [0.16441965103149414, 0.5]
# EPOCH= 1 BATCH= 298 g_loss= [12.403295516967773, 0.0] 	d_loss= [0.16512000560760498, 0.5]
# EPOCH= 1 BATCH= 299 g_loss= [12.32763957977295, 0.0] 	d_loss= [0.16428157687187195, 0.5]
# EPOCH= 1 BATCH= 300 g_loss= [12.192717552185059, 0.0] 	d_loss= [0.16458666324615479, 0.5]
# EPOCH= 1 BATCH= 301 g_loss= [12.238391876220703, 0.0] 	d_loss= [0.1648392677307129, 0.5]
# EPOCH= 1 BATCH= 302 g_loss= [12.384007453918457, 0.0] 	d_loss= [0.16431251168251038, 0.5]
# EPOCH= 1 BATCH= 303 g_loss= [12.470555305480957, 0.0] 	d_loss= [0.16410884261131287, 0.5]
# EPOCH= 1 BATCH= 304 g_loss= [12.57919692993164, 0.0] 	d_loss= [0.16445820033550262, 0.5]
# EPOCH= 1 BATCH= 305 g_loss= [12.522275924682617, 0.0] 	d_loss= [0.16469457745552063, 0.5]
# EPOCH= 1 BATCH= 306 g_loss= [12.276220321655273, 0.0] 	d_loss= [0.1642337143421173, 0.5]
# EPOCH= 1 BATCH= 307 g_loss= [12.146440505981445, 0.0] 	d_loss= [0.1645524948835373, 0.5]
# EPOCH= 1 BATCH= 308 g_loss= [12.331220626831055, 0.0] 	d_loss= [0.16456404328346252, 0.5]
# EPOCH= 1 BATCH= 309 g_loss= [12.74992561340332, 0.0] 	d_loss= [0.16456565260887146, 0.5]
# EPOCH= 1 BATCH= 310 g_loss= [12.897768020629883, 0.0] 	d_loss= [0.16430796682834625, 0.5]
# EPOCH= 1 BATCH= 311 g_loss= [12.521547317504883, 0.0] 	d_loss= [0.16506247222423553, 0.5]
# EPOCH= 1 BATCH= 312 g_loss= [12.191110610961914, 0.0] 	d_loss= [0.1641346961259842, 0.5]
# EPOCH= 1 BATCH= 313 g_loss= [12.322745323181152, 0.0] 	d_loss= [0.1646147519350052, 0.5]
# EPOCH= 1 BATCH= 314 g_loss= [12.657941818237305, 0.0] 	d_loss= [0.16395869851112366, 0.5]
# EPOCH= 1 BATCH= 315 g_loss= [12.881712913513184, 0.0] 	d_loss= [0.1642061173915863, 0.5]
# EPOCH= 1 BATCH= 316 g_loss= [12.59107494354248, 0.0] 	d_loss= [0.16465765237808228, 0.5]
# EPOCH= 1 BATCH= 317 g_loss= [12.007850646972656, 0.0] 	d_loss= [0.1643352210521698, 0.5]
# EPOCH= 1 BATCH= 318 g_loss= [11.867368698120117, 0.0] 	d_loss= [0.1648198962211609, 0.5]
# EPOCH= 1 BATCH= 319 g_loss= [12.255247116088867, 0.0] 	d_loss= [0.16433610022068024, 0.5]
# EPOCH= 1 BATCH= 320 g_loss= [12.87541675567627, 0.0] 	d_loss= [0.16454671323299408, 0.5]
# EPOCH= 1 BATCH= 321 g_loss= [12.785813331604004, 0.0] 	d_loss= [0.16468891501426697, 0.5]
# EPOCH= 1 BATCH= 322 g_loss= [12.161243438720703, 0.0] 	d_loss= [0.16458214819431305, 0.5]
# EPOCH= 1 BATCH= 323 g_loss= [11.830111503601074, 0.0] 	d_loss= [0.16442295908927917, 0.5]
# EPOCH= 1 BATCH= 324 g_loss= [12.23054313659668, 0.0] 	d_loss= [0.16464868187904358, 0.5]
# EPOCH= 1 BATCH= 325 g_loss= [12.716915130615234, 0.0] 	d_loss= [0.16402457654476166, 0.5]
# EPOCH= 1 BATCH= 326 g_loss= [12.959296226501465, 0.0] 	d_loss= [0.16413961350917816, 0.5]
# EPOCH= 1 BATCH= 327 g_loss= [12.55807113647461, 0.0] 	d_loss= [0.1646198034286499, 0.5]
# EPOCH= 1 BATCH= 328 g_loss= [12.152183532714844, 0.0] 	d_loss= [0.16429361701011658, 0.5]
# EPOCH= 1 BATCH= 329 g_loss= [12.034690856933594, 0.0] 	d_loss= [0.16430513560771942, 0.5]
# EPOCH= 1 BATCH= 330 g_loss= [12.496624946594238, 0.0] 	d_loss= [0.16469953954219818, 0.5]
# EPOCH= 1 BATCH= 331 g_loss= [12.942935943603516, 0.0] 	d_loss= [0.1643754541873932, 0.5]
# EPOCH= 1 BATCH= 332 g_loss= [12.95289421081543, 0.0] 	d_loss= [0.16436365246772766, 0.5]
# EPOCH= 1 BATCH= 333 g_loss= [12.613911628723145, 0.0] 	d_loss= [0.16430211067199707, 0.5]
# EPOCH= 1 BATCH= 334 g_loss= [12.287506103515625, 0.0] 	d_loss= [0.16410212218761444, 0.5]
# EPOCH= 1 BATCH= 335 g_loss= [12.346784591674805, 0.0] 	d_loss= [0.16413316130638123, 0.5]
# EPOCH= 1 BATCH= 336 g_loss= [12.867067337036133, 0.0] 	d_loss= [0.1643369048833847, 0.5]
# EPOCH= 1 BATCH= 337 g_loss= [13.043693542480469, 0.0] 	d_loss= [0.16433745622634888, 0.5]
# EPOCH= 1 BATCH= 338 g_loss= [12.976311683654785, 0.0] 	d_loss= [0.16397710144519806, 0.5]
# EPOCH= 1 BATCH= 339 g_loss= [12.531989097595215, 0.0] 	d_loss= [0.16442498564720154, 0.5]
# EPOCH= 1 BATCH= 340 g_loss= [12.378148078918457, 0.0] 	d_loss= [0.16390976309776306, 0.5]
# EPOCH= 1 BATCH= 341 g_loss= [12.497016906738281, 0.0] 	d_loss= [0.16422110795974731, 0.5]
# EPOCH= 1 BATCH= 342 g_loss= [12.913637161254883, 0.0] 	d_loss= [0.16410639882087708, 0.5]
# EPOCH= 1 BATCH= 343 g_loss= [13.197301864624023, 0.0] 	d_loss= [0.163712739944458, 0.5]
# EPOCH= 1 BATCH= 344 g_loss= [13.020605087280273, 0.0] 	d_loss= [0.16473229229450226, 0.5]
# EPOCH= 1 BATCH= 345 g_loss= [12.64303207397461, 0.0] 	d_loss= [0.16426992416381836, 0.5]
# EPOCH= 1 BATCH= 346 g_loss= [12.48747444152832, 0.0] 	d_loss= [0.16387319564819336, 0.5]
# EPOCH= 1 BATCH= 347 g_loss= [12.720634460449219, 0.0] 	d_loss= [0.1641852855682373, 0.5]
# EPOCH= 1 BATCH= 348 g_loss= [12.987808227539062, 0.0] 	d_loss= [0.1638346016407013, 0.5]
# EPOCH= 1 BATCH= 349 g_loss= [13.074560165405273, 0.0] 	d_loss= [0.1638057976961136, 0.5]
# EPOCH= 1 BATCH= 350 g_loss= [12.853666305541992, 0.0] 	d_loss= [0.1642923355102539, 0.5]
# EPOCH= 1 BATCH= 351 g_loss= [12.790570259094238, 0.0] 	d_loss= [0.16397923231124878, 0.5]
# EPOCH= 1 BATCH= 352 g_loss= [12.899402618408203, 0.0] 	d_loss= [0.16423925757408142, 0.5]
# EPOCH= 1 BATCH= 353 g_loss= [12.948883056640625, 0.0] 	d_loss= [0.1639951467514038, 0.5]
# EPOCH= 1 BATCH= 354 g_loss= [12.863508224487305, 0.0] 	d_loss= [0.1637892723083496, 0.5]
# EPOCH= 1 BATCH= 355 g_loss= [12.814998626708984, 0.0] 	d_loss= [0.16402339935302734, 0.5]
# EPOCH= 1 BATCH= 356 g_loss= [12.81566333770752, 0.0] 	d_loss= [0.16421064734458923, 0.5]
# EPOCH= 1 BATCH= 357 g_loss= [12.910795211791992, 0.0] 	d_loss= [0.1640090048313141, 0.5]
# EPOCH= 1 BATCH= 358 g_loss= [12.93781852722168, 0.0] 	d_loss= [0.16410839557647705, 0.5]
# EPOCH= 1 BATCH= 359 g_loss= [12.802035331726074, 0.0] 	d_loss= [0.16407322883605957, 0.5]
# EPOCH= 1 BATCH= 360 g_loss= [12.743339538574219, 0.0] 	d_loss= [0.16402322053909302, 0.5]
# EPOCH= 1 BATCH= 361 g_loss= [12.729493141174316, 0.0] 	d_loss= [0.16403010487556458, 0.5]
# EPOCH= 1 BATCH= 362 g_loss= [12.969328880310059, 0.0] 	d_loss= [0.1641201376914978, 0.5]
# EPOCH= 1 BATCH= 363 g_loss= [13.224099159240723, 0.0] 	d_loss= [0.16392889618873596, 0.5]
# EPOCH= 1 BATCH= 364 g_loss= [13.18213176727295, 0.0] 	d_loss= [0.16399626433849335, 0.5]
# EPOCH= 1 BATCH= 365 g_loss= [13.012260437011719, 0.0] 	d_loss= [0.16379457712173462, 0.5]
# EPOCH= 1 BATCH= 366 g_loss= [12.815689086914062, 0.0] 	d_loss= [0.16444803774356842, 0.5]
# EPOCH= 1 BATCH= 367 g_loss= [12.878133773803711, 0.0] 	d_loss= [0.16388536989688873, 0.5]
# EPOCH= 1 BATCH= 368 g_loss= [13.103310585021973, 0.0] 	d_loss= [0.16387325525283813, 0.5]
# EPOCH= 1 BATCH= 369 g_loss= [13.194572448730469, 0.0] 	d_loss= [0.16368037462234497, 0.5]
# EPOCH= 1 BATCH= 370 g_loss= [13.127777099609375, 0.0] 	d_loss= [0.16390597820281982, 0.5]
# EPOCH= 1 BATCH= 371 g_loss= [13.123236656188965, 0.0] 	d_loss= [0.1637135148048401, 0.5]
# EPOCH= 1 BATCH= 372 g_loss= [13.121259689331055, 0.0] 	d_loss= [0.1638147234916687, 0.5]
# EPOCH= 1 BATCH= 373 g_loss= [13.057114601135254, 0.0] 	d_loss= [0.16389450430870056, 0.5]
# EPOCH= 1 BATCH= 374 g_loss= [13.139888763427734, 0.0] 	d_loss= [0.16400785744190216, 0.5]
# EPOCH= 1 BATCH= 375 g_loss= [13.201851844787598, 0.0] 	d_loss= [0.16368074715137482, 0.5]
# EPOCH= 1 BATCH= 376 g_loss= [13.148174285888672, 0.0] 	d_loss= [0.16375741362571716, 0.5]
# EPOCH= 1 BATCH= 377 g_loss= [12.963479995727539, 0.0] 	d_loss= [0.16396786272525787, 0.5]
# EPOCH= 1 BATCH= 378 g_loss= [13.031978607177734, 0.0] 	d_loss= [0.16379663348197937, 0.5]
# EPOCH= 1 BATCH= 379 g_loss= [13.184164047241211, 0.0] 	d_loss= [0.1640627086162567, 0.5]
# EPOCH= 1 BATCH= 380 g_loss= [13.0739107131958, 0.0] 	d_loss= [0.16458040475845337, 0.5]
# EPOCH= 1 BATCH= 381 g_loss= [12.973014831542969, 0.0] 	d_loss= [0.16393564641475677, 0.5]
# EPOCH= 1 BATCH= 382 g_loss= [12.884765625, 0.0] 	d_loss= [0.1635994017124176, 0.5]
# EPOCH= 1 BATCH= 383 g_loss= [13.131869316101074, 0.0] 	d_loss= [0.1637307107448578, 0.5]
# EPOCH= 1 BATCH= 384 g_loss= [13.226547241210938, 0.0] 	d_loss= [0.16370134055614471, 0.5]
# EPOCH= 1 BATCH= 385 g_loss= [12.894316673278809, 0.0] 	d_loss= [0.16408221423625946, 0.5]
# EPOCH= 1 BATCH= 386 g_loss= [12.522377967834473, 0.0] 	d_loss= [0.1635742485523224, 0.5]
# EPOCH= 1 BATCH= 387 g_loss= [12.555529594421387, 0.0] 	d_loss= [0.16377303004264832, 0.5]
# EPOCH= 1 BATCH= 388 g_loss= [12.917001724243164, 0.0] 	d_loss= [0.1640245020389557, 0.5]
# EPOCH= 1 BATCH= 389 g_loss= [12.982728958129883, 0.0] 	d_loss= [0.16382776200771332, 0.5]
# EPOCH= 1 BATCH= 390 g_loss= [12.853789329528809, 0.0] 	d_loss= [0.16355541348457336, 0.5]
# EPOCH= 1 BATCH= 391 g_loss= [12.556511878967285, 0.0] 	d_loss= [0.16361235082149506, 0.5]
# EPOCH= 1 BATCH= 392 g_loss= [12.477682113647461, 0.0] 	d_loss= [0.1639808714389801, 0.5]
# EPOCH= 1 BATCH= 393 g_loss= [12.543632507324219, 0.0] 	d_loss= [0.16361908614635468, 0.5]
# EPOCH= 1 BATCH= 394 g_loss= [13.001011848449707, 0.0] 	d_loss= [0.16427481174468994, 0.5]
# EPOCH= 1 BATCH= 395 g_loss= [13.181436538696289, 0.0] 	d_loss= [0.16372418403625488, 0.5]
# EPOCH= 1 BATCH= 396 g_loss= [12.913043975830078, 0.0] 	d_loss= [0.16414576768875122, 0.5]
# EPOCH= 1 BATCH= 397 g_loss= [12.802093505859375, 0.0] 	d_loss= [0.16356870532035828, 0.5]
# EPOCH= 1 BATCH= 398 g_loss= [12.775424003601074, 0.0] 	d_loss= [0.16378316283226013, 0.5]
# EPOCH= 1 BATCH= 399 g_loss= [13.129207611083984, 0.0] 	d_loss= [0.16376708447933197, 0.5]
# EPOCH= 1 BATCH= 400 g_loss= [13.533124923706055, 0.0] 	d_loss= [0.1636504828929901, 0.5]
# EPOCH= 1 BATCH= 401 g_loss= [13.384855270385742, 0.0] 	d_loss= [0.1641850471496582, 0.5]
# EPOCH= 1 BATCH= 402 g_loss= [12.98072338104248, 0.0] 	d_loss= [0.16367672383785248, 0.5]
# EPOCH= 1 BATCH= 403 g_loss= [12.973215103149414, 0.0] 	d_loss= [0.16362003982067108, 0.5]
# EPOCH= 1 BATCH= 404 g_loss= [13.223772048950195, 0.0] 	d_loss= [0.16383090615272522, 0.5]
# EPOCH= 1 BATCH= 405 g_loss= [13.422337532043457, 0.0] 	d_loss= [0.16408804059028625, 0.5]
# EPOCH= 1 BATCH= 406 g_loss= [13.426874160766602, 0.0] 	d_loss= [0.1638505607843399, 0.5]
# EPOCH= 1 BATCH= 407 g_loss= [13.264640808105469, 0.0] 	d_loss= [0.1634027063846588, 0.5]
# EPOCH= 1 BATCH= 408 g_loss= [13.308016777038574, 0.0] 	d_loss= [0.16349336504936218, 0.5]
# EPOCH= 1 BATCH= 409 g_loss= [13.44482421875, 0.0] 	d_loss= [0.16388201713562012, 0.5]
# EPOCH= 1 BATCH= 410 g_loss= [13.367494583129883, 0.0] 	d_loss= [0.16378331184387207, 0.5]
# EPOCH= 1 BATCH= 411 g_loss= [13.407600402832031, 0.0] 	d_loss= [0.16352787613868713, 0.5]
# EPOCH= 1 BATCH= 412 g_loss= [13.407333374023438, 0.0] 	d_loss= [0.16361457109451294, 0.5]
# EPOCH= 1 BATCH= 413 g_loss= [13.475279808044434, 0.0] 	d_loss= [0.16369172930717468, 0.5]
# EPOCH= 1 BATCH= 414 g_loss= [13.587554931640625, 0.0] 	d_loss= [0.16373372077941895, 0.5]
# EPOCH= 1 BATCH= 415 g_loss= [13.438276290893555, 0.0] 	d_loss= [0.16352775692939758, 0.5]
# EPOCH= 1 BATCH= 416 g_loss= [13.256597518920898, 0.0] 	d_loss= [0.1635381579399109, 0.5]
# EPOCH= 1 BATCH= 417 g_loss= [13.243730545043945, 0.0] 	d_loss= [0.16373828053474426, 0.5]
# EPOCH= 1 BATCH= 418 g_loss= [13.428174018859863, 0.0] 	d_loss= [0.16378244757652283, 0.5]
# EPOCH= 1 BATCH= 419 g_loss= [13.656152725219727, 0.0] 	d_loss= [0.16368016600608826, 0.5]
# EPOCH= 1 BATCH= 420 g_loss= [13.462675094604492, 0.0] 	d_loss= [0.16393201053142548, 0.5]
# EPOCH= 1 BATCH= 421 g_loss= [13.072986602783203, 0.0] 	d_loss= [0.1637692004442215, 0.5]
# EPOCH= 1 BATCH= 422 g_loss= [13.064607620239258, 0.0] 	d_loss= [0.16357791423797607, 0.5]
# EPOCH= 1 BATCH= 423 g_loss= [13.46173095703125, 0.0] 	d_loss= [0.1640171855688095, 0.5]
# EPOCH= 1 BATCH= 424 g_loss= [13.750690460205078, 0.0] 	d_loss= [0.16338974237442017, 0.5]
# EPOCH= 1 BATCH= 425 g_loss= [13.678357124328613, 0.0] 	d_loss= [0.1636580228805542, 0.5]
# EPOCH= 1 BATCH= 426 g_loss= [13.288661003112793, 0.0] 	d_loss= [0.16358475387096405, 0.5]
# EPOCH= 1 BATCH= 427 g_loss= [13.095330238342285, 0.0] 	d_loss= [0.16332601010799408, 0.5]
# EPOCH= 1 BATCH= 428 g_loss= [13.272034645080566, 0.0] 	d_loss= [0.16370448470115662, 0.5]
# EPOCH= 1 BATCH= 429 g_loss= [13.766408920288086, 0.0] 	d_loss= [0.1633690446615219, 0.5]
# EPOCH= 1 BATCH= 430 g_loss= [13.735577583312988, 0.0] 	d_loss= [0.1636272519826889, 0.5]
# EPOCH= 1 BATCH= 431 g_loss= [13.423022270202637, 0.0] 	d_loss= [0.1637052744626999, 0.5]
# EPOCH= 1 BATCH= 432 g_loss= [13.405047416687012, 0.0] 	d_loss= [0.16366638243198395, 0.5]
# EPOCH= 1 BATCH= 433 g_loss= [13.346281051635742, 0.0] 	d_loss= [0.16333512961864471, 0.5]
# EPOCH= 1 BATCH= 434 g_loss= [13.487886428833008, 0.0] 	d_loss= [0.16366469860076904, 0.5]
# EPOCH= 1 BATCH= 435 g_loss= [13.656782150268555, 0.0] 	d_loss= [0.1633535623550415, 0.5]
# EPOCH= 1 BATCH= 436 g_loss= [13.615299224853516, 0.0] 	d_loss= [0.16362351179122925, 0.5]
# EPOCH= 1 BATCH= 437 g_loss= [13.501642227172852, 0.0] 	d_loss= [0.1635625809431076, 0.5]
# EPOCH= 1 BATCH= 438 g_loss= [13.431207656860352, 0.0] 	d_loss= [0.16339176893234253, 0.5]
# EPOCH= 1 BATCH= 439 g_loss= [13.454843521118164, 0.0] 	d_loss= [0.16366896033287048, 0.5]
# EPOCH= 1 BATCH= 440 g_loss= [13.556079864501953, 0.0] 	d_loss= [0.1633320152759552, 0.5]
# EPOCH= 1 BATCH= 441 g_loss= [13.686052322387695, 0.0] 	d_loss= [0.16341839730739594, 0.5]
# EPOCH= 1 BATCH= 442 g_loss= [13.617965698242188, 0.0] 	d_loss= [0.16379162669181824, 0.5]
# EPOCH= 1 BATCH= 443 g_loss= [13.37099552154541, 0.0] 	d_loss= [0.16355779767036438, 0.5]
# EPOCH= 1 BATCH= 444 g_loss= [13.417794227600098, 0.0] 	d_loss= [0.16347381472587585, 0.5]
# EPOCH= 1 BATCH= 445 g_loss= [13.443196296691895, 0.0] 	d_loss= [0.16360315680503845, 0.5]
# EPOCH= 1 BATCH= 446 g_loss= [13.610321044921875, 0.0] 	d_loss= [0.1635550856590271, 0.5]
# EPOCH= 1 BATCH= 447 g_loss= [13.641551971435547, 0.0] 	d_loss= [0.16345906257629395, 0.5]
# EPOCH= 1 BATCH= 448 g_loss= [13.466753005981445, 0.0] 	d_loss= [0.16336436569690704, 0.5]
# EPOCH= 1 BATCH= 449 g_loss= [13.414480209350586, 0.0] 	d_loss= [0.16351431608200073, 0.5]
# EPOCH= 1 BATCH= 450 g_loss= [13.383310317993164, 0.0] 	d_loss= [0.16342765092849731, 0.5]
# EPOCH= 1 BATCH= 451 g_loss= [13.420204162597656, 0.0] 	d_loss= [0.16363805532455444, 0.5]
# EPOCH= 1 BATCH= 452 g_loss= [13.282562255859375, 0.0] 	d_loss= [0.16333606839179993, 0.5]
# EPOCH= 1 BATCH= 453 g_loss= [13.365047454833984, 0.0] 	d_loss= [0.1634942591190338, 0.5]
# EPOCH= 1 BATCH= 454 g_loss= [13.402912139892578, 0.0] 	d_loss= [0.16373325884342194, 0.5]
# EPOCH= 1 BATCH= 455 g_loss= [13.496370315551758, 0.0] 	d_loss= [0.1634465456008911, 0.5]
# EPOCH= 1 BATCH= 456 g_loss= [13.562419891357422, 0.0] 	d_loss= [0.16326355934143066, 0.5]
# EPOCH= 1 BATCH= 457 g_loss= [13.499675750732422, 0.0] 	d_loss= [0.16337800025939941, 0.5]
# EPOCH= 1 BATCH= 458 g_loss= [13.255182266235352, 0.0] 	d_loss= [0.163536936044693, 0.5]
# EPOCH= 1 BATCH= 459 g_loss= [13.206172943115234, 0.0] 	d_loss= [0.16355404257774353, 0.5]
# EPOCH= 1 BATCH= 460 g_loss= [13.347967147827148, 0.0] 	d_loss= [0.16350150108337402, 0.5]
# EPOCH= 1 BATCH= 461 g_loss= [13.417874336242676, 0.0] 	d_loss= [0.16346332430839539, 0.5]
# EPOCH= 1 BATCH= 462 g_loss= [13.430423736572266, 0.0] 	d_loss= [0.1635819971561432, 0.5]
# EPOCH= 1 BATCH= 463 g_loss= [13.339534759521484, 0.0] 	d_loss= [0.16350942850112915, 0.5]
# EPOCH= 1 BATCH= 464 g_loss= [13.26806926727295, 0.0] 	d_loss= [0.16352029144763947, 0.5]
# EPOCH= 1 BATCH= 465 g_loss= [13.348871231079102, 0.0] 	d_loss= [0.16331127285957336, 0.5]
# EPOCH= 1 BATCH= 466 g_loss= [13.412103652954102, 0.0] 	d_loss= [0.1634674370288849, 0.5]
# EPOCH= 1 BATCH= 467 g_loss= [13.311162948608398, 0.0] 	d_loss= [0.16351643204689026, 0.5]
# EPOCH= 1 BATCH= 468 g_loss= [13.220074653625488, 0.0] 	d_loss= [0.163543701171875, 0.5]
# EPOCH= 2 BATCH= 1 g_loss= [13.293560981750488, 0.0] 	d_loss= [0.16331984102725983, 0.5]
# EPOCH= 2 BATCH= 2 g_loss= [13.499979972839355, 0.0] 	d_loss= [0.16359993815422058, 0.5]
# EPOCH= 2 BATCH= 3 g_loss= [13.479884147644043, 0.0] 	d_loss= [0.163360133767128, 0.5]
# EPOCH= 2 BATCH= 4 g_loss= [13.21541690826416, 0.0] 	d_loss= [0.16362278163433075, 0.5]
# EPOCH= 2 BATCH= 5 g_loss= [12.921359062194824, 0.0] 	d_loss= [0.16385376453399658, 0.5]
# EPOCH= 2 BATCH= 6 g_loss= [13.05710220336914, 0.0] 	d_loss= [0.16357716917991638, 0.5]
# EPOCH= 2 BATCH= 7 g_loss= [13.344874382019043, 0.0] 	d_loss= [0.1635761260986328, 0.5]
# EPOCH= 2 BATCH= 8 g_loss= [13.591816902160645, 0.0] 	d_loss= [0.16355936229228973, 0.5]
# EPOCH= 2 BATCH= 9 g_loss= [13.484203338623047, 0.0] 	d_loss= [0.1634933203458786, 0.5]
# EPOCH= 2 BATCH= 10 g_loss= [13.140535354614258, 0.0] 	d_loss= [0.16359785199165344, 0.5]
# EPOCH= 2 BATCH= 11 g_loss= [13.153898239135742, 0.0] 	d_loss= [0.16383317112922668, 0.5]
# EPOCH= 2 BATCH= 12 g_loss= [13.55577564239502, 0.0] 	d_loss= [0.16346099972724915, 0.5]
# EPOCH= 2 BATCH= 13 g_loss= [13.74970817565918, 0.0] 	d_loss= [0.16348576545715332, 0.5]
# EPOCH= 2 BATCH= 14 g_loss= [13.431583404541016, 0.0] 	d_loss= [0.16362477838993073, 0.5]
# EPOCH= 2 BATCH= 15 g_loss= [13.101344108581543, 0.0] 	d_loss= [0.16334111988544464, 0.5]
# EPOCH= 2 BATCH= 16 g_loss= [13.180194854736328, 0.0] 	d_loss= [0.16353273391723633, 0.5]
# EPOCH= 2 BATCH= 17 g_loss= [13.35018539428711, 0.0] 	d_loss= [0.1637062132358551, 0.5]
# EPOCH= 2 BATCH= 18 g_loss= [13.526573181152344, 0.0] 	d_loss= [0.16317147016525269, 0.5]
# EPOCH= 2 BATCH= 19 g_loss= [13.528839111328125, 0.0] 	d_loss= [0.16349932551383972, 0.5]
# EPOCH= 2 BATCH= 20 g_loss= [13.362052917480469, 0.0] 	d_loss= [0.16317541897296906, 0.5]
# EPOCH= 2 BATCH= 21 g_loss= [13.251591682434082, 0.0] 	d_loss= [0.1632930040359497, 0.5]
# EPOCH= 2 BATCH= 22 g_loss= [13.365211486816406, 0.0] 	d_loss= [0.1633051335811615, 0.5]
# EPOCH= 2 BATCH= 23 g_loss= [13.517702102661133, 0.0] 	d_loss= [0.1633719503879547, 0.5]
# EPOCH= 2 BATCH= 24 g_loss= [13.399351119995117, 0.0] 	d_loss= [0.16349372267723083, 0.5]
# EPOCH= 2 BATCH= 25 g_loss= [13.302162170410156, 0.0] 	d_loss= [0.1633140593767166, 0.5]
# EPOCH= 2 BATCH= 26 g_loss= [13.2852783203125, 0.0] 	d_loss= [0.16318629682064056, 0.5]
# EPOCH= 2 BATCH= 27 g_loss= [13.389781951904297, 0.0] 	d_loss= [0.16341464221477509, 0.5]
# EPOCH= 2 BATCH= 28 g_loss= [13.57933521270752, 0.0] 	d_loss= [0.16334930062294006, 0.5]
# EPOCH= 2 BATCH= 29 g_loss= [13.593583106994629, 0.0] 	d_loss= [0.16348375380039215, 0.5]
# EPOCH= 2 BATCH= 30 g_loss= [13.381082534790039, 0.0] 	d_loss= [0.16336579620838165, 0.5]
# EPOCH= 2 BATCH= 31 g_loss= [13.372756004333496, 0.0] 	d_loss= [0.16333894431591034, 0.5]
# EPOCH= 2 BATCH= 32 g_loss= [13.510248184204102, 0.0] 	d_loss= [0.1632995754480362, 0.5]
# EPOCH= 2 BATCH= 33 g_loss= [13.684605598449707, 0.0] 	d_loss= [0.16354307532310486, 0.5]
# EPOCH= 2 BATCH= 34 g_loss= [13.695178985595703, 0.0] 	d_loss= [0.1632707566022873, 0.5]
# EPOCH= 2 BATCH= 35 g_loss= [13.607945442199707, 0.0] 	d_loss= [0.16321873664855957, 0.5]
# EPOCH= 2 BATCH= 36 g_loss= [13.414798736572266, 0.0] 	d_loss= [0.1636270135641098, 0.5]
# EPOCH= 2 BATCH= 37 g_loss= [13.55976676940918, 0.0] 	d_loss= [0.16325420141220093, 0.5]
# EPOCH= 2 BATCH= 38 g_loss= [13.748440742492676, 0.0] 	d_loss= [0.16341662406921387, 0.5]
# EPOCH= 2 BATCH= 39 g_loss= [13.677125930786133, 0.0] 	d_loss= [0.16359615325927734, 0.5]
# EPOCH= 2 BATCH= 40 g_loss= [13.49246597290039, 0.0] 	d_loss= [0.16326060891151428, 0.5]
# EPOCH= 2 BATCH= 41 g_loss= [13.397283554077148, 0.0] 	d_loss= [0.16329392790794373, 0.5]
# EPOCH= 2 BATCH= 42 g_loss= [13.620869636535645, 0.0] 	d_loss= [0.16346147656440735, 0.5]
# EPOCH= 2 BATCH= 43 g_loss= [13.793712615966797, 0.0] 	d_loss= [0.16318708658218384, 0.5]
# EPOCH= 2 BATCH= 44 g_loss= [13.658714294433594, 0.0] 	d_loss= [0.16336768865585327, 0.5]
# EPOCH= 2 BATCH= 45 g_loss= [13.46496295928955, 0.0] 	d_loss= [0.1632440835237503, 0.5]
# EPOCH= 2 BATCH= 46 g_loss= [13.469481468200684, 0.0] 	d_loss= [0.1632515788078308, 0.5]
# EPOCH= 2 BATCH= 47 g_loss= [13.684820175170898, 0.0] 	d_loss= [0.16319024562835693, 0.5]
# EPOCH= 2 BATCH= 48 g_loss= [13.796976089477539, 0.0] 	d_loss= [0.16334769129753113, 0.5]
# EPOCH= 2 BATCH= 49 g_loss= [13.643474578857422, 0.0] 	d_loss= [0.16353122889995575, 0.5]
# EPOCH= 2 BATCH= 50 g_loss= [13.47669792175293, 0.0] 	d_loss= [0.16315501928329468, 0.5]
# EPOCH= 2 BATCH= 51 g_loss= [13.578437805175781, 0.0] 	d_loss= [0.16326597332954407, 0.5]
# EPOCH= 2 BATCH= 52 g_loss= [13.647905349731445, 0.0] 	d_loss= [0.1633598357439041, 0.5]
# EPOCH= 2 BATCH= 53 g_loss= [13.618647575378418, 0.0] 	d_loss= [0.16314932703971863, 0.5]
# EPOCH= 2 BATCH= 54 g_loss= [13.595104217529297, 0.0] 	d_loss= [0.16313035786151886, 0.5]
# EPOCH= 2 BATCH= 55 g_loss= [13.671586990356445, 0.0] 	d_loss= [0.1631810963153839, 0.5]
# EPOCH= 2 BATCH= 56 g_loss= [13.607802391052246, 0.0] 	d_loss= [0.16333577036857605, 0.5]
# EPOCH= 2 BATCH= 57 g_loss= [13.625575065612793, 0.0] 	d_loss= [0.16324922442436218, 0.5]
# EPOCH= 2 BATCH= 58 g_loss= [13.443048477172852, 0.0] 	d_loss= [0.1632436215877533, 0.5]
# EPOCH= 2 BATCH= 59 g_loss= [13.516738891601562, 0.0] 	d_loss= [0.16351288557052612, 0.5]
# EPOCH= 2 BATCH= 60 g_loss= [13.625252723693848, 0.0] 	d_loss= [0.1632629632949829, 0.5]
# EPOCH= 2 BATCH= 61 g_loss= [13.737292289733887, 0.0] 	d_loss= [0.1633932888507843, 0.5]
# EPOCH= 2 BATCH= 62 g_loss= [13.68017864227295, 0.0] 	d_loss= [0.1633642613887787, 0.5]
# EPOCH= 2 BATCH= 63 g_loss= [13.595378875732422, 0.0] 	d_loss= [0.16342222690582275, 0.5]
# EPOCH= 2 BATCH= 64 g_loss= [13.618934631347656, 0.0] 	d_loss= [0.16324615478515625, 0.5]
# EPOCH= 2 BATCH= 65 g_loss= [13.615827560424805, 0.0] 	d_loss= [0.1631985306739807, 0.5]
# EPOCH= 2 BATCH= 66 g_loss= [13.684248924255371, 0.0] 	d_loss= [0.16323617100715637, 0.5]
# EPOCH= 2 BATCH= 67 g_loss= [13.798492431640625, 0.0] 	d_loss= [0.16320690512657166, 0.5]
# EPOCH= 2 BATCH= 68 g_loss= [13.711664199829102, 0.0] 	d_loss= [0.16312003135681152, 0.5]
# EPOCH= 2 BATCH= 69 g_loss= [13.503246307373047, 0.0] 	d_loss= [0.16336189210414886, 0.5]
# EPOCH= 2 BATCH= 70 g_loss= [13.653804779052734, 0.0] 	d_loss= [0.1631975919008255, 0.5]
# EPOCH= 2 BATCH= 71 g_loss= [13.854657173156738, 0.0] 	d_loss= [0.16316534578800201, 0.5]
# ...
# EPOCH= 3 BATCH= 84 g_loss= [14.003293991088867, 0.0] 	d_loss= [0.1627468466758728, 0.5]
# EPOCH= 3 BATCH= 85 g_loss= [14.33372688293457, 0.0] 	d_loss= [0.16277143359184265, 0.5]
# EPOCH= 3 BATCH= 86 g_loss= [14.278393745422363, 0.0] 	d_loss= [0.16281133890151978, 0.5]
# EPOCH= 3 BATCH= 87 g_loss= [14.00452709197998, 0.0] 	d_loss= [0.16274206340312958, 0.5]
# EPOCH= 3 BATCH= 88 g_loss= [14.11954402923584, 0.0] 	d_loss= [0.1628066897392273, 0.5]
# EPOCH= 3 BATCH= 89 g_loss= [14.275472640991211, 0.0] 	d_loss= [0.1627616286277771, 0.5]
# EPOCH= 3 BATCH= 90 g_loss= [14.284934997558594, 0.0] 	d_loss= [0.1627407968044281, 0.5]
# EPOCH= 3 BATCH= 91 g_loss= [14.16889476776123, 0.0] 	d_loss= [0.16277290880680084, 0.5]
# EPOCH= 3 BATCH= 92 g_loss= [14.164325714111328, 0.0] 	d_loss= [0.16275326907634735, 0.5]
# EPOCH= 3 BATCH= 93 g_loss= [14.255962371826172, 0.0] 	d_loss= [0.16279220581054688, 0.5]
# EPOCH= 3 BATCH= 94 g_loss= [14.231121063232422, 0.0] 	d_loss= [0.16275398433208466, 0.5]
# EPOCH= 3 BATCH= 95 g_loss= [14.107559204101562, 0.0] 	d_loss= [0.1628056764602661, 0.5]
# EPOCH= 3 BATCH= 96 g_loss= [14.04306411743164, 0.0] 	d_loss= [0.16278740763664246, 0.5]
# EPOCH= 3 BATCH= 97 g_loss= [14.222566604614258, 0.0] 	d_loss= [0.16283318400382996, 0.5]
# EPOCH= 3 BATCH= 98 g_loss= [14.281068801879883, 0.0] 	d_loss= [0.16271792352199554, 0.5]
# EPOCH= 3 BATCH= 99 g_loss= [14.175150871276855, 0.0] 	d_loss= [0.16276419162750244, 0.5]
# EPOCH= 3 BATCH= 100 g_loss= [14.074607849121094, 0.0] 	d_loss= [0.16270220279693604, 0.5]
# EPOCH= 3 BATCH= 101 g_loss= [14.104178428649902, 0.0] 	d_loss= [0.16278284788131714, 0.5]
# EPOCH= 3 BATCH= 102 g_loss= [14.209564208984375, 0.0] 	d_loss= [0.16278278827667236, 0.5]
# EPOCH= 3 BATCH= 103 g_loss= [14.13280200958252, 0.0] 	d_loss= [0.16275463998317719, 0.5]
# EPOCH= 3 BATCH= 104 g_loss= [14.102653503417969, 0.0] 	d_loss= [0.16279426217079163, 0.5]
# EPOCH= 3 BATCH= 105 g_loss= [14.121395111083984, 0.0] 	d_loss= [0.16270944476127625, 0.5]
# EPOCH= 3 BATCH= 106 g_loss= [14.035350799560547, 0.0] 	d_loss= [0.16270925104618073, 0.5]
# EPOCH= 3 BATCH= 107 g_loss= [14.041910171508789, 0.0] 	d_loss= [0.16278555989265442, 0.5]
# EPOCH= 3 BATCH= 108 g_loss= [14.081326484680176, 0.0] 	d_loss= [0.16274037957191467, 0.5]
# EPOCH= 3 BATCH= 109 g_loss= [13.946508407592773, 0.0] 	d_loss= [0.1628003716468811, 0.5]
# EPOCH= 3 BATCH= 110 g_loss= [14.05389404296875, 0.0] 	d_loss= [0.16278943419456482, 0.5]
# EPOCH= 3 BATCH= 111 g_loss= [14.133329391479492, 0.0] 	d_loss= [0.1627829372882843, 0.5]
# EPOCH= 3 BATCH= 112 g_loss= [14.095505714416504, 0.0] 	d_loss= [0.16273599863052368, 0.5]
# EPOCH= 3 BATCH= 113 g_loss= [14.015918731689453, 0.0] 	d_loss= [0.16276822984218597, 0.5]
# EPOCH= 3 BATCH= 114 g_loss= [14.109596252441406, 0.0] 	d_loss= [0.16276782751083374, 0.5]
# EPOCH= 3 BATCH= 115 g_loss= [14.101692199707031, 0.0] 	d_loss= [0.1627902388572693, 0.5]
# EPOCH= 3 BATCH= 116 g_loss= [14.055024147033691, 0.0] 	d_loss= [0.16278089582920074, 0.5]
# EPOCH= 3 BATCH= 117 g_loss= [14.118085861206055, 0.0] 	d_loss= [0.1627686470746994, 0.5]
# EPOCH= 3 BATCH= 118 g_loss= [14.168158531188965, 0.0] 	d_loss= [0.16277122497558594, 0.5]
# EPOCH= 3 BATCH= 119 g_loss= [14.13652229309082, 0.0] 	d_loss= [0.16270576417446136, 0.5]
# EPOCH= 3 BATCH= 120 g_loss= [14.07259750366211, 0.0] 	d_loss= [0.16279533505439758, 0.5]
# EPOCH= 3 BATCH= 121 g_loss= [14.094208717346191, 0.0] 	d_loss= [0.16271959245204926, 0.5]
# EPOCH= 3 BATCH= 122 g_loss= [14.274673461914062, 0.0] 	d_loss= [0.16273586452007294, 0.5]
# EPOCH= 3 BATCH= 123 g_loss= [14.205595970153809, 0.0] 	d_loss= [0.16274414956569672, 0.5]
# EPOCH= 3 BATCH= 124 g_loss= [14.15591049194336, 0.0] 	d_loss= [0.16274937987327576, 0.5]
# EPOCH= 3 BATCH= 125 g_loss= [14.125886917114258, 0.0] 	d_loss= [0.162736177444458, 0.5]
# EPOCH= 3 BATCH= 126 g_loss= [14.302248001098633, 0.0] 	d_loss= [0.16273361444473267, 0.5]
# EPOCH= 3 BATCH= 127 g_loss= [14.333602905273438, 0.0] 	d_loss= [0.1627410352230072, 0.5]
# EPOCH= 3 BATCH= 128 g_loss= [14.120010375976562, 0.0] 	d_loss= [0.16287419199943542, 0.5]
# EPOCH= 3 BATCH= 129 g_loss= [13.98727035522461, 0.0] 	d_loss= [0.16275888681411743, 0.5]
# EPOCH= 3 BATCH= 130 g_loss= [14.26769733428955, 0.0] 	d_loss= [0.16287076473236084, 0.5]
# EPOCH= 3 BATCH= 131 g_loss= [14.33879280090332, 0.0] 	d_loss= [0.162721648812294, 0.5]
# EPOCH= 3 BATCH= 132 g_loss= [14.251572608947754, 0.0] 	d_loss= [0.1627800166606903, 0.5]
# EPOCH= 3 BATCH= 133 g_loss= [14.133880615234375, 0.0] 	d_loss= [0.16267743706703186, 0.5]
# EPOCH= 3 BATCH= 134 g_loss= [14.265108108520508, 0.0] 	d_loss= [0.16275820136070251, 0.5]
# EPOCH= 3 BATCH= 135 g_loss= [14.290132522583008, 0.0] 	d_loss= [0.1627720296382904, 0.5]
# EPOCH= 3 BATCH= 136 g_loss= [14.123634338378906, 0.0] 	d_loss= [0.16280461847782135, 0.5]
# EPOCH= 3 BATCH= 137 g_loss= [14.173839569091797, 0.0] 	d_loss= [0.1627059131860733, 0.5]
# EPOCH= 3 BATCH= 138 g_loss= [14.285106658935547, 0.0] 	d_loss= [0.16274526715278625, 0.5]
# EPOCH= 3 BATCH= 139 g_loss= [14.264392852783203, 0.0] 	d_loss= [0.16272765398025513, 0.5]
# EPOCH= 3 BATCH= 140 g_loss= [14.322015762329102, 0.0] 	d_loss= [0.1627335250377655, 0.5]
# EPOCH= 3 BATCH= 141 g_loss= [14.258369445800781, 0.0] 	d_loss= [0.16275234520435333, 0.5]
# EPOCH= 3 BATCH= 142 g_loss= [14.150697708129883, 0.0] 	d_loss= [0.16270533204078674, 0.5]
# EPOCH= 3 BATCH= 143 g_loss= [14.190407752990723, 0.0] 	d_loss= [0.16274215281009674, 0.5]
# EPOCH= 3 BATCH= 144 g_loss= [14.334878921508789, 0.0] 	d_loss= [0.16275207698345184, 0.5]
# EPOCH= 3 BATCH= 145 g_loss= [14.284271240234375, 0.0] 	d_loss= [0.16276702284812927, 0.5]
# EPOCH= 3 BATCH= 146 g_loss= [14.163421630859375, 0.0] 	d_loss= [0.1627214252948761, 0.5]
# EPOCH= 3 BATCH= 147 g_loss= [14.075678825378418, 0.0] 	d_loss= [0.16271665692329407, 0.5]
# EPOCH= 3 BATCH= 148 g_loss= [14.262468338012695, 0.0] 	d_loss= [0.16276875138282776, 0.5]
# EPOCH= 3 BATCH= 149 g_loss= [14.288311958312988, 0.0] 	d_loss= [0.16280442476272583, 0.5]
# EPOCH= 3 BATCH= 150 g_loss= [14.087825775146484, 0.0] 	d_loss= [0.16273391246795654, 0.5]
# EPOCH= 3 BATCH= 151 g_loss= [13.999373435974121, 0.0] 	d_loss= [0.16272681951522827, 0.5]
# EPOCH= 3 BATCH= 152 g_loss= [14.248671531677246, 0.0] 	d_loss= [0.16277821362018585, 0.5]
# EPOCH= 3 BATCH= 153 g_loss= [14.315956115722656, 0.0] 	d_loss= [0.16272622346878052, 0.5]
# EPOCH= 3 BATCH= 154 g_loss= [13.86407470703125, 0.0] 	d_loss= [0.1629081666469574, 0.5]
# EPOCH= 3 BATCH= 155 g_loss= [13.956304550170898, 0.0] 	d_loss= [0.16285067796707153, 0.5]
# EPOCH= 3 BATCH= 156 g_loss= [14.292882919311523, 0.0] 	d_loss= [0.16279427707195282, 0.5]
# EPOCH= 3 BATCH= 157 g_loss= [14.156917572021484, 0.0] 	d_loss= [0.16288700699806213, 0.5]
# EPOCH= 3 BATCH= 158 g_loss= [13.964578628540039, 0.0] 	d_loss= [0.16271403431892395, 0.5]
# EPOCH= 3 BATCH= 159 g_loss= [14.05783748626709, 0.0] 	d_loss= [0.16278159618377686, 0.5]
# EPOCH= 3 BATCH= 160 g_loss= [14.181570053100586, 0.0] 	d_loss= [0.16279789805412292, 0.5]
# EPOCH= 3 BATCH= 161 g_loss= [14.13548469543457, 0.0] 	d_loss= [0.16273203492164612, 0.5]
# EPOCH= 3 BATCH= 162 g_loss= [13.960668563842773, 0.0] 	d_loss= [0.1627471148967743, 0.5]
# EPOCH= 3 BATCH= 163 g_loss= [13.989957809448242, 0.0] 	d_loss= [0.16280986368656158, 0.5]
# EPOCH= 3 BATCH= 164 g_loss= [14.235182762145996, 0.0] 	d_loss= [0.16273656487464905, 0.5]
# EPOCH= 3 BATCH= 165 g_loss= [14.238155364990234, 0.0] 	d_loss= [0.1627286970615387, 0.5]
# EPOCH= 3 BATCH= 166 g_loss= [14.051609992980957, 0.0] 	d_loss= [0.1627483069896698, 0.5]
# EPOCH= 3 BATCH= 167 g_loss= [14.093685150146484, 0.0] 	d_loss= [0.16279810667037964, 0.5]
# EPOCH= 3 BATCH= 168 g_loss= [14.18004035949707, 0.0] 	d_loss= [0.16275501251220703, 0.5]
# EPOCH= 3 BATCH= 169 g_loss= [14.189727783203125, 0.0] 	d_loss= [0.16276758909225464, 0.5]
# EPOCH= 3 BATCH= 170 g_loss= [14.12621021270752, 0.0] 	d_loss= [0.16276681423187256, 0.5]
# EPOCH= 3 BATCH= 171 g_loss= [14.11990737915039, 0.0] 	d_loss= [0.16276352107524872, 0.5]
# EPOCH= 3 BATCH= 172 g_loss= [14.226526260375977, 0.0] 	d_loss= [0.16270661354064941, 0.5]
# EPOCH= 3 BATCH= 173 g_loss= [14.172435760498047, 0.0] 	d_loss= [0.16272710263729095, 0.5]
# EPOCH= 3 BATCH= 174 g_loss= [14.173885345458984, 0.0] 	d_loss= [0.16270384192466736, 0.5]
# EPOCH= 3 BATCH= 175 g_loss= [14.236135482788086, 0.0] 	d_loss= [0.1627286672592163, 0.5]
# EPOCH= 3 BATCH= 176 g_loss= [14.164320945739746, 0.0] 	d_loss= [0.1628674566745758, 0.5]
# EPOCH= 3 BATCH= 177 g_loss= [14.066335678100586, 0.0] 	d_loss= [0.16272655129432678, 0.5]
# EPOCH= 3 BATCH= 178 g_loss= [14.08022689819336, 0.0] 	d_loss= [0.1628093123435974, 0.5]
# EPOCH= 3 BATCH= 179 g_loss= [14.147974967956543, 0.0] 	d_loss= [0.16271504759788513, 0.5]
# EPOCH= 3 BATCH= 180 g_loss= [14.161894798278809, 0.0] 	d_loss= [0.16279469430446625, 0.5]
# EPOCH= 3 BATCH= 181 g_loss= [14.091075897216797, 0.0] 	d_loss= [0.16272875666618347, 0.5]
# EPOCH= 3 BATCH= 182 g_loss= [14.047091484069824, 0.0] 	d_loss= [0.1627587080001831, 0.5]
# EPOCH= 3 BATCH= 183 g_loss= [14.209935188293457, 0.0] 	d_loss= [0.16270771622657776, 0.5]
# EPOCH= 3 BATCH= 184 g_loss= [14.170784950256348, 0.0] 	d_loss= [0.16274546086788177, 0.5]
# EPOCH= 3 BATCH= 185 g_loss= [14.118094444274902, 0.0] 	d_loss= [0.1626930981874466, 0.5]
# EPOCH= 3 BATCH= 186 g_loss= [13.959001541137695, 0.0] 	d_loss= [0.16271868348121643, 0.5]
# EPOCH= 3 BATCH= 187 g_loss= [14.052310943603516, 0.0] 	d_loss= [0.1627732217311859, 0.5]
# EPOCH= 3 BATCH= 188 g_loss= [14.223102569580078, 0.0] 	d_loss= [0.16273203492164612, 0.5]
# EPOCH= 3 BATCH= 189 g_loss= [14.155757904052734, 0.0] 	d_loss= [0.1627243459224701, 0.5]
# EPOCH= 3 BATCH= 190 g_loss= [14.025209426879883, 0.0] 	d_loss= [0.16272684931755066, 0.5]
# EPOCH= 3 BATCH= 191 g_loss= [14.071878433227539, 0.0] 	d_loss= [0.16274289786815643, 0.5]
# EPOCH= 3 BATCH= 192 g_loss= [14.224187850952148, 0.0] 	d_loss= [0.16271831095218658, 0.5]
# EPOCH= 3 BATCH= 193 g_loss= [14.036189079284668, 0.0] 	d_loss= [0.16280850768089294, 0.5]
# EPOCH= 3 BATCH= 194 g_loss= [13.954629898071289, 0.0] 	d_loss= [0.1627165675163269, 0.5]
# EPOCH= 3 BATCH= 195 g_loss= [14.205743789672852, 0.0] 	d_loss= [0.16279442608356476, 0.5]
# EPOCH= 3 BATCH= 196 g_loss= [14.14098834991455, 0.0] 	d_loss= [0.16279888153076172, 0.5]
# EPOCH= 3 BATCH= 197 g_loss= [13.91995620727539, 0.0] 	d_loss= [0.16273467242717743, 0.5]
# EPOCH= 3 BATCH= 198 g_loss= [14.083813667297363, 0.0] 	d_loss= [0.1627751886844635, 0.5]
# EPOCH= 3 BATCH= 199 g_loss= [13.963846206665039, 0.0] 	d_loss= [0.16275101900100708, 0.5]
# EPOCH= 3 BATCH= 200 g_loss= [13.898846626281738, 0.0] 	d_loss= [0.16274937987327576, 0.5]
# EPOCH= 3 BATCH= 201 g_loss= [14.015968322753906, 0.0] 	d_loss= [0.1627480387687683, 0.5]
# EPOCH= 3 BATCH= 202 g_loss= [14.015192985534668, 0.0] 	d_loss= [0.16270944476127625, 0.5]
# EPOCH= 3 BATCH= 203 g_loss= [13.966270446777344, 0.0] 	d_loss= [0.16276316344738007, 0.5]
# EPOCH= 3 BATCH= 204 g_loss= [13.892549514770508, 0.0] 	d_loss= [0.16269996762275696, 0.5]
# EPOCH= 3 BATCH= 205 g_loss= [14.000053405761719, 0.0] 	d_loss= [0.1627720594406128, 0.5]
# EPOCH= 3 BATCH= 206 g_loss= [14.122688293457031, 0.0] 	d_loss= [0.16276699304580688, 0.5]
# EPOCH= 3 BATCH= 207 g_loss= [13.826377868652344, 0.0] 	d_loss= [0.16282618045806885, 0.5]
# EPOCH= 3 BATCH= 208 g_loss= [13.932794570922852, 0.0] 	d_loss= [0.1629445105791092, 0.5]
# EPOCH= 3 BATCH= 209 g_loss= [14.332576751708984, 0.0] 	d_loss= [0.16277921199798584, 0.5]
# EPOCH= 3 BATCH= 210 g_loss= [14.109489440917969, 0.0] 	d_loss= [0.16289955377578735, 0.5]
# EPOCH= 3 BATCH= 211 g_loss= [13.898332595825195, 0.0] 	d_loss= [0.16270464658737183, 0.5]
# EPOCH= 3 BATCH= 212 g_loss= [13.994518280029297, 0.0] 	d_loss= [0.16274255514144897, 0.5]
# EPOCH= 3 BATCH= 213 g_loss= [14.178778648376465, 0.0] 	d_loss= [0.1627645641565323, 0.5]
# EPOCH= 3 BATCH= 214 g_loss= [14.095575332641602, 0.0] 	d_loss= [0.16289828717708588, 0.5]
# EPOCH= 3 BATCH= 215 g_loss= [13.965219497680664, 0.0] 	d_loss= [0.16268602013587952, 0.5]
# EPOCH= 3 BATCH= 216 g_loss= [13.909536361694336, 0.0] 	d_loss= [0.16271671652793884, 0.5]
# EPOCH= 3 BATCH= 217 g_loss= [14.2308988571167, 0.0] 	d_loss= [0.16277068853378296, 0.5]
# EPOCH= 3 BATCH= 218 g_loss= [14.196344375610352, 0.0] 	d_loss= [0.16277803480625153, 0.5]
# EPOCH= 3 BATCH= 219 g_loss= [13.853975296020508, 0.0] 	d_loss= [0.16276773810386658, 0.5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f4f89b900ce6> in <module>
#      20         noise2 = np.random.normal(0,1,size=[BATCH_SIZE,NOISE_DIM])
#      21         y2 = np.ones(BATCH_SIZE)
# ---> 22         g_loss = model.train_on_batch(noise2,y2)
#      23
#      24         print("EPOCH=",e+1,"BATCH=",nob+1,"g_loss=", g_loss, "\td_loss=",d_loss)
#
# ~\.conda\envs\my_tensor\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1796       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1797                                                     y, sample_weight,
# -> 1798                                                     class_weight)
#    1799       self.train_function = self.make_train_function()
#    1800       logs = self.train_function(iterator)
#
# ~\.conda\envs\my_tensor\lib\site-packages\keras\engine\data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1601     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1602   dataset = strategy.experimental_distribute_dataset(dataset)
# -> 1603   return iter(dataset)
#    1604
#    1605
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     698   def _create_iterator(self, dataset):
#     699     # pylint: disable=protected-access
# --> 700     dataset = dataset._apply_options()
#     701
#     702     # Store dataset reference to ensure that dataset is alive when this iterator
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in _apply_options(self)
#     461       dataset = _OptimizeDataset(dataset, graph_rewrites.enabled,
#     462                                  graph_rewrites.disabled,
# --> 463                                  graph_rewrites.default, graph_rewrite_configs)
#     464
#     465     # (4) Apply stats aggregator options
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, optimization_configs)
#    4894         self._optimizations_default,
#    4895         optimization_configs=optimization_configs,
# -> 4896         **self._flat_structure)
#    4897
#    4898     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#
# ~\.conda\envs\my_tensor\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in optimize_dataset_v2(input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, output_types, output_shapes, optimization_configs, name)
#    4171         optimizations_disabled, optimizations_default, "output_types",
#    4172         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 4173         optimization_configs)
#    4174       return _result
#    4175     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
